# %%
import numpy as np
import matplotlib.pyplot as plt

y1 = [0.25365, 0.233577, 0.218978, 0.166058, 0.162409, 0.162409, 0.158759, 0.136861, 0.131387, 0.135036, 
     0.135036, 0.133212, 0.133212, 0.133212, 0.133212, 0.133212, 0.133212, 0.133212, 0.133212, 0.133212]
x1 = np.arange(1, 21)

plt.figure(figsize=(18, 9))
plt.title('Lab4 Analysis')
plt.plot(x1, y1, '*-', color='b', label="miss_rate")
for a, b in zip(x1, y1):
    plt.text(a, b, b, ha='center', va='bottom', fontsize=9)
plt.xlabel('m')
plt.locator_params(axis="y", nbins=10)
plt.legend(loc="best")
